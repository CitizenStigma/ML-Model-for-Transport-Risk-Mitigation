# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
all = pd.read_pickle("/content/drive/My Drive/all.pkl")
all
# Out:
#          speed  msla  temp  feels_like  pressure  humidity  clouds  \
# 6          0.0  48.0  7.73        6.86    1024.0      70.0    94.0
# 7          0.0  48.0  7.73        6.86    1024.0      70.0    94.0
# 9          0.0  28.0  7.73        6.86    1024.0      70.0    94.0
# 10         0.0  28.0  7.73        6.86    1024.0      70.0    94.0
# 18         0.0  73.0  7.73        6.86    1024.0      70.0    94.0
# ...        ...   ...   ...         ...       ...       ...     ...
# 1236727    0.0  73.0  7.73        6.86    1024.0      70.0    94.0
# 1236728    0.0  28.0  7.73        6.86    1024.0      70.0    94.0
# 1236729    0.0  28.0  7.73        6.86    1024.0      70.0    94.0
# 1236730    0.0  48.0  7.73        6.86    1024.0      70.0    94.0
# 1236731    0.0  48.0  7.73        6.86    1024.0      70.0    94.0
#
#          visibility  wind_speed  wind_gust  wind_deg  rain  snow  measurement  \
# 6           10000.0        1.68       3.55     322.0   0.0   0.0  temperature
# ...

# %%
all_temp = all[all.measurement=="temperature"].drop(columns=["measurement"])
all_humi = all[all.measurement=="humidity"].drop(columns=["measurement"])

# %% [markdown]
# # Temperature

# %%
# import sweetviz as sv

# %%
# report = sv.analyze(all_temp)
# report.show_notebook()

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.4/484.4 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 22.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from pycaret.regression import *
s = setup(all_temp, target = 'value')
# Out:
# <style type="text/css">
# #T_6a7bf_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6a7bf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a7bf_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6a7bf_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a7bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a7bf_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6a7bf_row0_col1" class="data row0 col1" >4502</td>
#     </tr>
#     <tr>
#       <th id="T_6a7bf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a7bf_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6a7bf_row1_col1" class="data row1 col1" >value</td>
#     </tr>
#     <tr>
#       <th id="T_6a7bf_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# best = compare_models(exclude=['omp', 'par',' huber', 'lar', 'llar', 'lasso', 'en', 'br', 'ridge', 'lr', 'knn', 'rf', 'et', 'xgboost'])
# best = create_model('dt')
best = compare_models(include=['omp', 'par', 'huber', 'lar', 'llar', 'lasso', 'en', 'br', 'ridge', 'lr', 'knn', 'dt'])
# Out:
# <style type="text/css">
# #T_70da4 th {
#   text-align: left;
# }
# ...

# %%
# best_tuned = tune_model(best, optimize='MAE')

# %%
plot_model(best, plot='error')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Humidity

# %%
ss = setup(all_humi, target = 'value')
# Out:
# <style type="text/css">
# #T_bdf21_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bdf21" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdf21_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bdf21_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdf21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdf21_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bdf21_row0_col1" class="data row0 col1" >5451</td>
#     </tr>
#     <tr>
#       <th id="T_bdf21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bdf21_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bdf21_row1_col1" class="data row1 col1" >value</td>
#     </tr>
#     <tr>
#       <th id="T_bdf21_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
besth = compare_models(include=['omp', 'par', 'huber', 'lar', 'llar', 'lasso', 'en', 'br', 'ridge', 'lr', 'knn', 'dt'])
# Out:
# <style type="text/css">
# #T_a5fce th {
#   text-align: left;
# }
# ...

# %%
plot_model(besth, plot='error')

# %%
evaluate_model(besth)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
evaluate_model(besth)
